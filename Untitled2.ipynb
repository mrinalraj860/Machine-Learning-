# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
check=pd.read_csv('Student_Marks.csv')

# %%
array=np.array(check)

# %%
x=array[:,:2]
y=array[:,2:3]

# %%
plt.plot(x,y)
